# %%
from utils import *

# %% [markdown]
# Visualize the bifurcation of the system by plotting three phase diagrams at representative values of α.

# %%
initial_condition = [0, 1.8]
grid_precision = 1000

plot_bifurcation_field(-1, initial_condition, grid_precision)
plt.show()

plot_bifurcation_field(0, initial_condition, grid_precision)
plt.show()

plot_bifurcation_field(1, initial_condition, grid_precision)
plt.show()

# %% [markdown]
# For α = 1, numerically compute and visualize two orbits of the system forward in time, starting at the point (2, 0) and at (0.5, 0).

# %%
initial_conditions = [[2, 0], [0.5, 0]]
alpha = 1
grid_precision = 1000
w = 2.1

plot_bifurcation_field_multiple_starts(alpha, initial_conditions, grid_precision, w=w)
plt.show()

# %% [markdown]
# Visualize the bifurcation surface (i.e. all points (x, α1, α2) where x˙ = 0) of the cusp bifurcation in a 3D plot, with α1, α2 on the bottom plane and x in the third direction.

# %%
plot_cusp_bifurcation(elev=0, azim=0)
plot_cusp_bifurcation(elev=0, azim=10)
plot_cusp_bifurcation(elev=10, azim=0)

# %%
plot_cusp_bifurcation(elev=30, azim=70, width=5)
plot_cusp_bifurcation(elev=30, azim=90, width=5)
plot_cusp_bifurcation(elev=30, azim=120, width=5)
