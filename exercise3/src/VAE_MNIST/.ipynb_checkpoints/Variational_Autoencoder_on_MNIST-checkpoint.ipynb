# %% [markdown]
# # Variational Autoencoder for MNIST
#
#
# ## What we will do:
#
# In this exercise, we want you to implement and to train a VAE.
#
# Dataset
#
# Use the MNIST dataset. You can download it using tensorflow, using
# tensorflow.keras.datasets.mnist.load data()
#
# The tutorial to VAE linked in the introduction also describes how to obtain the data. Note: do not binarise
# MNIST, only normalise the pixel values between 0 and 1, and split it into a training and a test set.
#
# Model
#
# Use a two-dimensional latent space. Use a multivariate diagonal Gaussian distribution as approximate
# posterior qϕ(z|x). The encoder neural network, which outputs the mean and standard deviation of qϕ(z|x),
# should consist of 2 hidden layers (dense/fully connected) with 256 units each and ReLU activation functions.
# Use also a multivariate diagonal Gaussian distribution as likelihood pθ(x|z). The decoder neural network, which
# outputs only the mean of pθ(x|z), should consist of 2 hidden layers (dense/fully connected) with 256 units
# each and ReLU activation functions. Implement the standard deviation for the decoder distribution as
# one (!) floating-point, trainable variable (make it a variable of the model, i.e. so that it does not depend on
# the input x as all the other layer outputs do). Use a multivariate diagonal standard normal distribution as
# prior p(z). Note: using a Bernoulli likelihood, as it is the case in most tutorials, is only possible for binarised
# versions of MNIST—so you should not do it here.

# %%
# For automatic file reloading
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ### We import the neccessary libraries

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

from exercise_code.VAE import VAE
from exercise_code.sampling import Sampling
from exercise_code.task_3_plots import plot_losses, plot_generated, plot_all

# %% [markdown]
# ### Set all the required parameters

# %%
parameters = {
    "input_shape": (28, 28, 1),
    "output_shape": 784,
    "intermediate_layers": 256,
    "latent_dim": 2,
    "adam_learning_rate": 0.001,
    "batch_size": 128,
    "epochs": 100
}

# %% [markdown]
# ### Build the encoder

# %%
encoder_inputs = keras.Input(shape=parameters["input_shape"])
x = layers.Flatten()(encoder_inputs)

# First hidden layer
x = layers.Dense(parameters["intermediate_layers"], activation="relu", name="hidden_layer_1")(x)
# Second hidden layer
x = layers.Dense(parameters["intermediate_layers"], activation="relu", name="hidden_layer_2")(x)

z_mean = layers.Dense(parameters["latent_dim"], name="z_mean")(x)
z_log_var = layers.Dense(parameters["latent_dim"], name="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 28, 28, 1)]  0           []
#
#  flatten_2 (Flatten)            (None, 784)          0           ['input_5[0][0]']
#
#  hidden_layer_1 (Dense)         (None, 256)          200960      ['flatten_2[0][0]']
#
#  hidden_layer_2 (Dense)         (None, 256)          65792       ['hidden_layer_1[0][0]']
#
#  z_mean (Dense)                 (None, 2)            514         ['hidden_layer_2[0][0]']
#
#  z_log_var (Dense)              (None, 2)            514         ['hidden_layer_2[0][0]']
#
#  sampling_2 (Sampling)          (None, 2)            0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 267,780
# Trainable params: 267,780
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Build the decoder

# %%
latent_inputs = keras.Input(shape=(parameters["latent_dim"],))

# First hidden layer
X = layers.Dense(parameters["intermediate_layers"], activation="relu", name="hidden_layer_1")(latent_inputs)
# Second hidden layer
X = layers.Dense(parameters["intermediate_layers"], activation="relu", name="hidden_layer_2")(X)

decoder_outputs = layers.Dense(parameters["output_shape"], activation="sigmoid", name="output")(X)
decoder_outputs = layers.Reshape(parameters["input_shape"], name="reshape")(decoder_outputs)
decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 2)]               0
#
#  hidden_layer_1 (Dense)      (None, 256)               768
#
#  hidden_layer_2 (Dense)      (None, 256)               65792
#
#  output (Dense)              (None, 784)               201488
#
#  reshape (Reshape)           (None, 28, 28, 1)         0
#
# =================================================================
# Total params: 268,048
# Trainable params: 268,048
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the VAE and display all plots

# %%
# Perform the experiments

# Load dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
x_train = np.expand_dims(x_train, -1).astype("float32") / 255
x_test = np.expand_dims(x_test, -1).astype("float32") / 255


# Create an instance of the VAE class
vae = VAE(encoder, decoder, scale=28*28)

# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=parameters["adam_learning_rate"])
vae.compile(optimizer)

loss_history = {
    'loss': [],
    'reconstruction_loss': [],
    'kl_loss': []
}

# Train the model for each stage and accumulate the losses
for stage, num_epochs in enumerate([1, 4, 20, 25]):
    # Train the model for the specified number of epochs
    h = vae.fit(x_train, epochs=num_epochs, batch_size=parameters["batch_size"])
    
    # Concatenate the dictionaries
    for key in loss_history.keys():
        loss_history[key] = loss_history[key] + h.history[key]

    # Plot all displays
    plot_all(vae, x_test, y_test, loss_history)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 10>()
#       6 x_test = np.expand_dims(x_test, -1).astype("float32") / 255
#       9 # Create an instance of the VAE class
# ---> 10 vae = VAE(encoder, decoder)
#      12 # Compile the model
#      13 optimizer = tf.keras.optimizers.Adam(learning_rate=parameters["adam_learning_rate"])
#
# File ~\Documents\GitHub\crowd-modeling-and-simulation\exercise3\src\VAE_MNIST\exercise_code\VAE.py:8, in VAE.__init__(self, encoder, decoder, latent_dim, name, **kwargs)
#       7 def __init__(self, encoder, decoder, latent_dim=2, name="vae", **kwargs):
# ----> 8     super(VAE, self).__init__(name=name, **kwargs)
#       9     self.encoder = encoder
#      10     self.decoder = decoder
#
# TypeError: super(type, obj): obj must be an instance or subtype of type

# %%
# Plot after convergence (Continued training until 100 epochs were reached)
h = vae.fit(x_train, epochs=50, batch_size=128)

for key in loss_history.keys():
        loss_history[key] = loss_history[key] + h.history[key]

plot_all(vae, x_test, y_test, loss_history)
# Out:
# Epoch 1/50
# 469/469 [==============================] - 7s 16ms/step - loss: 133.6459 - reconstruction_loss: 129.8281 - kl_loss: 3.9209
# Epoch 2/50
# 469/469 [==============================] - 7s 16ms/step - loss: 134.7835 - reconstruction_loss: 130.7853 - kl_loss: 3.8925
# Epoch 3/50
# 469/469 [==============================] - 7s 16ms/step - loss: 134.1853 - reconstruction_loss: 129.8475 - kl_loss: 3.9220
# Epoch 4/50
# 469/469 [==============================] - 7s 16ms/step - loss: 133.7283 - reconstruction_loss: 129.6693 - kl_loss: 3.9179
# Epoch 5/50
# 469/469 [==============================] - 7s 15ms/step - loss: 133.2271 - reconstruction_loss: 129.5277 - kl_loss: 3.9232
# Epoch 6/50
# 469/469 [==============================] - 7s 16ms/step - loss: 133.3046 - reconstruction_loss: 129.3847 - kl_loss: 3.9314
# Epoch 7/50
# 469/469 [==============================] - 7s 16ms/step - loss: 133.1496 - reconstruction_loss: 129.4054 - kl_loss: 3.9333
# Epoch 8/50
# 469/469 [==============================] - 7s 16ms/step - loss: 133.2593 - reconstruction_loss: 129.3906 - kl_loss: 3.9365
# Epoch 9/50
# 469/469 [==============================] - 7s 15ms/step - loss: 133.0817 - reconstruction_loss: 129.3321 - kl_loss: 3.9543
# Epoch 10/50
# 469/469 [==============================] - 7s 16ms/step - loss: 132
50
# 469/469 [==============================] - 7s 16ms/step - loss: 131.2875 - reconstruction_loss: 127.1802 - kl_loss: 4.0481
# Epoch 43/50
# 469/469 [==============================] - 7s 16ms/step - loss: 131.1458 - reconstruction_loss: 127.1789 - kl_loss: 4.0467
# Epoch 44/50
# 469/469 [==============================] - 7s 16ms/step - loss: 131.3564 - reconstruction_loss: 127.3193 - kl_loss: 4.0443
# Epoch 45/50
# 469/469 [==============================] - 7s 16ms/step - loss: 131.2488 - reconstruction_loss: 127.1102 - kl_loss: 4.0510
# Epoch 46/50
# 469/469 [==============================] - 7s 16ms/step - loss: 131.0451 - reconstruction_loss: 127.3299 - kl_loss: 4.0459
# Epoch 47/50
# 469/469 [==============================] - 7s 16ms/step - loss: 131.3136 - reconstruction_loss: 127.2618 - kl_loss: 4.0442
# Epoch 48/50
# 469/469 [==============================] - 7s 16ms/step - loss: 131.2858 - reconstruction_loss: 127.1240 - kl_loss: 4.0441
# Epoch 49/50
# 469/469 [==============================] - 7s 16ms/step - loss: 130.9317 - reconstruction_loss: 126.8847 - kl_loss: 4.0556
# Epoch 50/50
# 469/469 [==============================] - 7s 16ms/step - loss: 131.0206 - reconstruction_loss: 126.8598 - kl_loss: 4.0549
# Plotting all losses
# Plotting latent space
# Plotting reconstructions
# Plotting generated digits
# Plotting 2D manifold

# %% [markdown]
# ### Change the latent space dimension to 32

# %%
# Change latent_dim in the parameters variable
parameters["latent_dim"] = 32
parameters
# Out:
# {'input_shape': (28, 28, 1),
#  'output_shape': 784,
#  'intermediate_layers': 256,
#  'latent_dim': 32,
#  'adam_learning_rate': 0.001,
#  'batch_size': 128,
#  'epochs': 100}

# %% [markdown]
# ### Train the VAE in the new latent dimension

# %%
# Perform the experiment
### IMPORTANT: The ENCODER and DECODER set up cells need to be ran again to restart the training and change their latent sizes

# Load dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
x_train = np.expand_dims(x_train, -1).astype("float32") / 255
x_test = np.expand_dims(x_test, -1).astype("float32") / 255


# Create an instance of the VAE class
vae = VAE(encoder, decoder)

# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=parameters["adam_learning_rate"])
vae.compile(optimizer)

# Plot after the 100th epoch
h = vae.fit(x_train, epochs=parameters["epochs"], batch_size=parameters["batch_size"])

print("Plotting losses")
plot_losses(h.history)

print("Plotting generated digits")
plot_generated(vae)
# Out:
# Epoch 1/100
# 469/469 [==============================] - 4s 6ms/step - loss: 0.3105 - reconstruction_loss: 0.2737 - kl_loss: 0.0010
# Epoch 2/100
# 168/469 [=========>....................] - ETA: 1s - loss: 0.2643 - reconstruction_loss: 0.2639 - kl_loss: 6.7403e-04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [10], in <cell line: 18>()
#      15 vae.compile(optimizer)
#      17 # Plot after the 100th epoch
# ---> 18 h = vae.fit(x_train, epochs=parameters["epochs"], batch_size=parameters["batch_size"])
#      20 print("Plotting losses")
#      21 plot_losses(h.history)
#
# File ~\anaconda3\envs\i2dl\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\i2dl\lib\site-packages\keras\engine\training.py:1690, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1688 # No error, now safe to assign to logs.
#    1689 logs = tmp_logs
# -> 1690 end_step = step + data_handler.step_increment
#    1691 callbacks.on_train_batch_end(end_step, logs)
#    1692 if self.stop_training:
#
# File ~\anaconda3\envs\i2dl\lib\site-packages\keras\engine\data_adapter.py:1395, in DataHandler.step_increment(self)
#    1392             self._current_step += steps_remaining
#    1393             self._steps_per_execution.assign(original_spe)
# -> 1395 @property
#    1396 def step_increment(self):
#    1397     """The number to increment the step for `on_batch_end` methods."""
#    1398     return self._step_increment
#
# KeyboardInterrupt:
